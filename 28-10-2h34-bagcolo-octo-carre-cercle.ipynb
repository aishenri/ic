# %%
# %display latex
var("y")
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="black",alpha=1)
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),
fillcolor="red",alpha=1)
pc = implicit_plot(x^2+y^2-8, (x,-3,3), (y,-3,3),
plot_points=4, zorder=5)
p1 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="green",alpha=0.3)
p2 = polygon(((0,0),(1,2.5),(2.5,1)),
             color="cyan",alpha=0.3)
p3 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="yellow",alpha=0.3)
p4 = polygon(((0,0),(-2.5,-1),(-2.5,1)),
             color="blue",alpha=0.3)
p5 = polygon(((0,0),(-2.5,-1),(-1,-2.5)),
             color="red",alpha=0.3)
p6 = polygon(((0,0),(2.5,1),(2.5,-1)),
             color="violet",alpha=0.3)
p7 = polygon(((0,0),(2.5,-1),(1,-2.5)),
             color="brown",alpha=0.3)
p8 = polygon(((0,0),(1,-2.5),(-1,-2.5)),
             color="orange",alpha=0.3)
r=2/sqrt(n(pi))
cp=line([(-1,-1),(-1,1),(1,1)])
cq=line([(1,1),(1,-1),(-1,-1)])
c0=circle((0,0),r,color="red",alpha=0.5)
c1=circle((-1,0),1,color="white",alpha=0.5)
c2=circle((1,0),1,color="white",alpha=0.5)
c3=circle((0,-1),1,color="white",alpha=0.5)
c4=circle((0,1),1,color="white",alpha=0.5)
show(a+b+pc+p1+p2+p3+p4+p5+p6+p7+p8+c1+cp+cq+c2+c3+c4+c0,
figsize=10,fontsize=8,axes=True,frame=True,gridlines="minor",
gridlinesstyle=dict(color="lightgrey",linestyle="-",alpha=0.3)  )
# Out:
# Graphics object consisting of 20 graphics primitives

# %% [markdown]
# Le carré bleu est en quadrature avec le cercle rouge. Les triangles le sont ils aussi ?
# Le carré et le cercle font 4, et l'octogone 20

# %%
show("circonf de l'octogone=",4*4)
# Out:
# "circonf de l'octogone=" 16

# %%
r=4/sqrt(n(pi));print ("aire du cercle=",round(n(pi)*r^2))
# Out:
# aire du cercle= 16

# %%
1.12837916709551*2

# %%
print ("remarquable=",round(2*n(pi)*2.25675833419102,2))

# %% [markdown]
# carré 2= 5*2=10

# %%
print "triangle x 4 =",round(2.5*(2/2)*4)

# %%
var("nt ba ha");nt=8;ba=2;ha=2.5
aioc=nt*(ba*ha)/2;print"aire octo =",round(aioc)

# %%
ca=2
aica=ca*ca;print"aire carré =",round(aica)

# %%
r=2/sqrt(n(pi));
print "aire du cercle=",n(pi)*r^2

# %%
print "aire du cercle yx=",n(pi)*(2^2)

# %%
yx=sqrt(n(pi)*2^2);yx

# %%
print "trinaire 16^3=",16^3

# %%
r=64/sqrt(n(pi));
print ("binaire(aire cercle r=64/sqrt(pi) =",round(n(pi)*r^2))

# %%
r=2/sqrt(n(pi));
print ("binaire(aire cercle =",round((n(pi)*r^2)))
