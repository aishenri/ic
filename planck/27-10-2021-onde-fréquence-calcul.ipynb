# %% [markdown]
# Longueur d'onde par énergie
# $E=\frac{hc}{\lambda}$

# %%
h=6.626E-34;c=299792458;j=2.88E-19;nm=1E+9
l=h*c/j*nm;show(round(l,1)," nm")
# Out:
# 689.7 ' nm'

# %% [markdown]
# vitesse dans l'eau longueur d'onde $\lambda=\frac{v}{f}$

# %%
v=c/1.33;f=4E14  # vitesse c dans l'eau 
lo=v/f*nm;show(round(lo,1)," nm")
# Out:
# 563.5 ' nm'

# %% [markdown]
# Changement de milieu=changement de $\lambda$=même $f$ : $\lambda=\frac{\frac{v}{n}}{f}=\frac{v}{nf}$
#
# Mon avis : Comme la célérité et la longueur d'onde sont la même chose pour le photon, il est possible de baisser ou augmenter la vitesse
#
# indice de réfraction négatif, vitesse supraluminique.
#
# ç=314159265.3 (ç et c sont des fréquences angulaires chirales, c'est à dire de rotation, couple énantiomères : dextro ç et lévo c )

# %%
Zd=360;Zl=376;ç=314159265.3;c=299792458

# %%
r=ç/c;r
# Out:
# 1.04792251077911

# %% [markdown]
# Le yin-yang sont la parfaite représentation de ces 2 lumières, ce qui pose la question : Que connaissait ils déjà que nous ne connaissions pas encore ?
#
# Que signifie ces 2 symboles à l'origine. $\pi$ ou bien [-1 0 1], Le père Amiot dans son mémoire stipule que c'est une progression géométrique sur une suite arithmétique : trinaire sur binaire, 3/2.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# http://www.calendrier-chinois.org/drupal/yin-yang-mouvements-et-energies
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Je doute qu'à l'origine le yin représente la lune et le yang le soleil, je pense plutôt qu'ils avaient découvert le deuxième soleil ? Ce que les scientifiques appellent l'énergie noire, qui en fait est tout simplement l'éther qu'ils ont banni de leur terminologie avec erreur !
