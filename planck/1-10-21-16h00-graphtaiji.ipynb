# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="lightgray",alpha=0.2)
p=plot(f,(x,-2,2),color='white',fill=-sqrt(4-x^2),
fillcolor="lightsalmon",alpha=0.1)
b = circle((0,0),2,color="lightgray",alpha=0.5)
show(a+p,figsize=2,axes=False,aspect_ratio=1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
var("y")
dx=-x/2.5;df=plot(dx,x,-2.5,2.5,color="brown")
dn=-x*2.5;ni=plot(dn,x,-1,1,color="orange")
d1=x/2.5;n1=plot(d1,x,-2.5,2.5,color="green")
d2=x*2.5;n2=plot(d2,x,-1.,1.,color="violet")
ce=circle((0,0),2.7,color="red");ci=circle((0,0),2,color="black")
h = implicit_plot(x^2+y^2-8,(-3,3),(-3,3),plot_points=4)
show(h+ce+ni+n1+ni+n2+ci+df+a+p,figsize=4,axes=False,
aspect_ratio=1,gridlines=False,frame=False,fontsize=6)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
df=plot(dx,x,-2.5,2.5,color="brown",
fill=True,fillcolor="green")

# %%
show(h+ce+ni+n1+ni+n2+ci+df+a+p,figsize=4,axes=False,
aspect_ratio=1,gridlines=False,frame=False,fontsize=6)
# Out:
# Graphics object consisting of 13 graphics primitives
