# %%
from sage.plot.plot import graphics_array
r=2/sqrt(n(pi));r
p3=plot(circle((0,0),r,color="red",
fill=True,alpha=0.2,)+polygon(((-1,1),(1,1),
(1,-1),(-1,-1)),color="blue",alpha=0.2,
thickness=1,frame=True,axes=True));
p2= circle((0,0),r,color="red",
        fill=True,alpha=0.2,fontsize=6)  
p1=polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2,
       thickness=1,frame=True,axes=True);
g = graphics_array([p1,p2,p3]);
g.show(frame=False,figsize=10,gridlines="minor",gridlinesstyle=dict(color="cyan",
linestyle="-",alpha=0.7))
# Out:
# Graphics Array of size 1 x 3

# %%
i = CC.0;li=line([i, 0.7+0.7*i]);i1=line([i, -0.7+0.7*i])
c=circle((0,0),1,color="red");o=point((0.5,0.868))
v=line([(0,0),(0.7,0.7)],color="violet",linestyle="--")
lb=text("\u2630",(-0.25,0.6),color="blue",fontsize=18,rotation=27)
i2=line([-i,0.7-0.7*i]);i3=line([-i,-0.7-0.7*i])
i4=line([-i^2,0.7-0.7*i]);i5=line([-i^2,0.7+0.7*i])
i6=line([i^2,-0.7-0.7*-i]);i7=line([i^2,-0.7+0.7*-i])
v1=line([(0,0),(-0.7,0.7)],color="green",linestyle="--")
v2=line([(0,0),(0.7,-0.7)],color="orange",linestyle="--")
v3=line([(0,0),(-0.7,-0.7)],color="red",linestyle="--")
v4=line([(1,0),(0,0)],color="salmon",linestyle="--")
v5=line([(-1,0),(0,0)],color="black",linestyle="--")
v6=line([(0,-1),(0,0)],color="yellow",linestyle="--")
v7=line([(0,0),(0,1)],color="blue",linestyle="--")
pp=li+i1+c+v+lb+v1+v2+v3+v4+v5+v6+v7+i2+i3+i4+i5+i6+i7
p=graphics_array([pp]);
p.show(frame=False,figsize=3,axes=False,gridlines="minor",gridlinesstyle=dict(color="cyan",
linestyle="-",alpha=0.7))
# Out:
# Graphics Array of size 1 x 1

# %%
lb=text("\u2630",(-0.25,0.65),color="blue",fontsize=18,rotation=27)
lb7=text("\u2637",(0.25,-0.65),color="blue",fontsize=18,rotation=27)
lb1=text("\u2631",(0.25,0.65),color="blue",fontsize=18,rotation=155)
lb6=text("\u2636",(-0.28,-0.6),color="blue",fontsize=18,rotation=160)
lb2=text("\u2632",(0.65,0.25),color="blue",fontsize=18,rotation=115)
lb5=text("\u2635",(-0.65,-0.25),color="blue",fontsize=18,rotation=115)
lb3=text("\u2633",(-0.60,0.25),color="blue",fontsize=18,rotation=70)
lb4=text("\u2634",(0.6,-0.25),color="blue",fontsize=18,rotation=70)
pb=lb+lb1+lb2+lb3+lb4+lb5+lb6+lb7+li+i1+c+v+lb+v1+v2+v3+v4+v5+v6+v7+i2+i3+i4+i5+i6+i7
p=graphics_array([pp,pb]);
p.show(frame=False,figsize=5,axes=False,gridlines="minor",gridlinesstyle=dict(color="cyan",
linestyle="-",alpha=0.7))
# Out:
# Graphics Array of size 1 x 2

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),fillcolor="black",alpha=1)
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),fillcolor="red",alpha=1)
pn = polygon(((0,0),(0,1),(0.7,0.7)),color="cyan",alpha=0.9)
ne = polygon(((0,0),(1,0),(0.7,0.7)),color="violet",alpha=0.9)
so = polygon(((0,0),(-1,0),(-0.7,-0.7)),color="red",alpha=0.9)
ps = polygon(((0,0),(0,-1),(0.7,-0.7)),color="lightgreen",alpha=0.9)
sp = polygon(((0,0),(0,1),(-0.7,0.7)),color="green",alpha=0.9)
se = polygon(((0,0),(1,0),(0.7,-0.7)),color="salmon",alpha=0.5)
es = polygon(((0,0),(-1,0),(-0.7,0.7)),color="yellow",alpha=0.9)
sn = polygon(((0,0),(0,-1),(-0.7,-0.7)),color="blue",alpha=0.9)
np = polygon(((0,0),(0,8),(5.7,5.7)),color="cyan",alpha=0.5)
gr = polygon(((0,0),(0,8),(-5.7,5.7)),color="green",alpha=0.9)
en = polygon(((0,0),(8,0),(5.7,5.7)),color="violet",alpha=0.5)
os = polygon(((0,0),(-8,0),(-5.7,-5.7)),color="red",alpha=0.9)
sp = polygon(((0,0),(0,-8),(5.7,-5.7)),color="lightgreen",alpha=0.9)
ka = polygon(((0,0),(8,0),(5.7,-5.7)),color="salmon",alpha=0.9)
ja = polygon(((0,0),(-8,0),(-5.7,5.7)),color="yellow",alpha=0.9)
bl = polygon(((0,0),(0,-8),(-5.7,-5.7)),color="blue",alpha=0.9)
cc=circle((0,0),2,color="white")

# %%
pb=lb+lb1+lb2+lb3+lb4+lb5+lb6+lb7+li+i1+c+v+lb+v1+v2+v3+v4+v5+v6+v7+i2+i3+i4+i5+i6+i7
pc=np+en+os+sp+se+sn+sp+es+ka+gr+ja+bl+a+b+cc
p=graphics_array([pp,pb,pc,p3]);
p.show(frame=False,figsize=10,axes=False,gridlines="minor",gridlinesstyle=dict(color="cyan",
linestyle="-",alpha=0.7))
# Out:
# Graphics Array of size 1 x 4

# %%
lp=text("\u2630",(-2,5),color="white",fontsize=50,rotation=27)
lp7=text("\u2637",(2,-5),color="white",fontsize=50,rotation=27)
lp1=text("\u2631",(2,5),color="white",fontsize=50,rotation=155)
lp6=text("\u2636",(-2,-5),color="white",fontsize=50,rotation=160)
lp2=text("\u2632",(5,2),color="white",fontsize=50,rotation=115)
lp5=text("\u2635",(-5,-2),color="white",fontsize=50,rotation=115)
lp3=text("\u2633",(-5,2),color="white",fontsize=50,rotation=70)
lp4=text("\u2634",(5,-2),color="white",fontsize=50,rotation=70)

# %%
pd=lp+lp1+lp2+lp3+lp4+lp5+lp6+lp7+np+en+os+sp+se+sn+sp+es+ka+gr+ja+bl+a+b+cc
p=graphics_array([pp,pb,pc,pd]);
p.show(frame=False,figsize=20,axes=False,gridlines="minor",gridlinesstyle=dict(color="cyan",
linestyle="-",alpha=0.7))
# Out:
# Graphics Array of size 1 x 4
