# %%
B=-5*x^2+2+x-1

# %%
b=-5*x^2+2*x-1;b
# Out:
# -5*x^2 + 2*x - 1

# %%
a=-5*(-8/5)^2+(-8/5*2)-1;a
# Out:
# -17

# %%
p=plot((-5*x^2)+(2+x-1),x,-20,20)

# %%
show(p,frame= True,axes=False,gridlines="major")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# %display latex
solve(B==1,x)
# Out:
# [x == (1/5), x == 0]

# %%
solve(b==0,x)
# Out:
# [x == (-2/5*I + 1/5), x == (2/5*I + 1/5)]
