# %%
dr=x*pi/2;nr=plot(dr,x,0,1.047,color="red",linestyle="--")
ce=circle((0,0),2.85,color="red");ci=circle((0,0),2,color="black")
a1 = arc((0,0), 2.85, angle=pi/4,sector=(pi/4,1*pi/-4),thickness=2)
a2 = arc((0,0), 2, angle=pi/6,color="red",sector=(pi/-6,0.9*pi/6))
a3 = arc((0,0), 2, angle=pi/2.7,color="green",sector=(pi/8,1*pi/-8))

# %%
la=x*pi/pi;al=plot(la,x,0 ,2,color="blue",linestyle="--")
lb=text("\u2630",(2.4,2.6),color="blue",fontsize=18)
lt=text("$\\frac{\\pi}{4}:45^o $",(2.4,2.6),color="blue",fontsize=18)
li=text("$i$",(-0.2,2.5),color="red",fontsize=18)
show(ce+ci+a1+a2+a3+al+lt+li,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=5,fontsize=8,
frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
deg(x)= x*180/n(pi);deg(n(pi)/4)
# Out:
# 45.0000000000000

# %% [markdown]
# Le nombre complexe $i$ se présente comme coefficient de la quadrature du cercle $i=r=1.128$

# %%
from sage.plot.plot import graphics_array
r=2/sqrt(n(pi));r
p3=plot(circle((0,0),r,color="red",fill=True,alpha=0.2,)+\
polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2,
        thickness=1,frame=True,axes=True));
p2= circle((0,0),r,color="red",
        fill=True,alpha=0.2,fontsize=6)  
p1=polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2,
       thickness=1,frame=True,axes=True);
g = graphics_array([p1,p2,p3]);
g.show(frame=False,figsize=10,gridlines="minor",gridlinesstyle=dict(color="cyan",
linestyle="-",alpha=0.7))
# Out:
# Graphics Array of size 1 x 3

# %%
r=2/sqrt(n(pi));r
# Out:
# 1.12837916709551

# %%
ci=circle((0,0),r,color="red",fill=True,alpha=0.2,)
po=polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2,
        thickness=1,frame=True,axes=True)
show(po+ci,figsize=3,fontsize=4,)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
lb=text("\u2630",(2.4,2.6),color="blue",fontsize=18)
