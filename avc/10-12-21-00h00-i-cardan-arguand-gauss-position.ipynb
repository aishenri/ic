# %% [markdown]
# https://www.lespritsorcier.org/blogs-membres/origine-du-nombre-imaginaire-i/
#
# Gauss : $\sqrt-1$ pose un problème ? (ou pas ?)
#
# On abouti à une contradiction :
#
# $\sqrt a \sqrt b=\sqrt ab$
#
# $\sqrt -1 \sqrt -1=(\sqrt -1)^2=-1$
#
# $\sqrt -1 -1 =\sqrt(-1)^2=\sqrt1=1$
#
# L'opposé d'un nombre a est l'unique nombre b tel que a+b=0; il se note - a
#
# Il n'y a pas contradiction, les parenthèses donne un  résultat opposé. Avec un logiciel on ne rencontre pas celle-ci : Opposé de 1 = -1
#
# Pourtant il reste un problème obscure : $\sqrt -1=i$ a-t-il une autre valeur réelle décimale, en d'autre terme : Quelle est sa position fondamentale quand $|z|$ ?
#
# L'inverse d'un nombre a non nul est l'unique nombre b tel que a×b=1 ; il se note $\frac{1}{a}$
#
# $z=a+b.i$  et $|z|=\sqrt a²+b²$ (Où est $i$ ?)

# %%
# %display latex
show(LatexExpr(r""))
# Out:
# $$\newcommand{\Bold}[1]{\mathbf{#1}}$$

# %%
a = 1;b = 250;r = 3;l = 5E-2;c = 5E-5;
t=text("i",(-0.2,0.2),color="red")
p=polygon([(-0.5,-0.5),(-0.5,0.5),(0.5,0.5),(0.5,0),
    (0.5,-0.5)], color="black",fill=False)
show(p+t,gridlines="minor",figsize=3,fontsize=4,gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=False,axes=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=text("i",(-0.2,0.2),color="red")
x1=plot(x*1,x,0,1/3.14,linestyle="--")
show(p+x1+t,gridlines="minor",figsize=3,fontsize=5,gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
c0=circle((0,0),1/2,color="red")
show(p+x1+c0,gridlines="minor",figsize=5,fontsize=5,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
p=polygon([(-0.5,-0.5),(-0.5,0.5),(0.5,0.5),(0.5,0),
    (0.5,-0.5)], color="black",fill=False)
tn=text("$i\\natural$",(-0.03,0.53),color="red")
td=text("$i\\sharp$",(0.38,0.38),color="blue")
tg=text("$i\\flat$",(-0.38,0.38),color="black")
x1=plot(x*1,x,0,0.35,linestyle="--")
x2=plot(x*-1,x,-0.35,0,color="black",linestyle="--")
show(p+x1+x2+c0+td+tg+tn,gridlines="minor",figsize=5,fontsize=5,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=False,axes=True)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
n(i/2)^2+1
# Out:
# 0.750000000000000

# %%
n(i/2)^2*-1
# Out:
# 0.250000000000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ii=e^(-n(pi)/2);si=sqrt(ii)

# %%
deg(x)=x*180/n(pi);deg(si)# degrés
# Out:
# 26.1233304400881

# %%
n(sqrt(i)) # -1
# Out:
# 0.707106781186548 + 0.707106781186547*I

# %%
n(0.8+0.6*i)
# Out:
# 0.800000000000000 + 0.600000000000000*I

# %%
n(si)
# Out:
# 0.455938127765996

# %%
cx=circle((0,0),sqrt(2.0),color="red")
q=circle((0,0),1,color="green")
cy=circle((0,0),1,color="black");r=2/sqrt(n(pi))
ax = arc((0,0), sqrt(2.0), angle=pi/4, 
sector=(pi/4,1*pi/-4),thickness=2)
ay = arc((0,0), 1, angle=pi/6,color="red", 
sector=(pi/-6,0.9*pi/6),thickness=2)
az = arc((0,0), 1, angle=pi/2.7,color="green", 
sector=(pi/7.5,1*pi/-7.85),thickness=2)
po=polygon([[0,0],[0,1],[1,1],[1,0]],fill=False)
dr=x;nr=plot(dr,x,-1,1,color="black",linestyle="--")
b=x/0.52;pb=plot(b,x,0,0.65,color="black")
d=x;pd=plot(d,x,0,1,color="red")
show(cx+cy+po+q+pd+pb,
xmax=1.42,xmin=0,ymax=1.42,ymin=0,
gridlines="minor",figsize=10,fontsize=6,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=True,axes=False)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
deg(0.65)
# Out:
# 37.2422566835035

# %%
(i/2.0)^2
# Out:
# -0.250000000000000

# %%
deg(0.25)
# Out:
# 14.3239448782706

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b=x/0.59;pb=plot(b,x,0,0.72,color="black")
cr=circle((0,0),r,color="black",linestyle="--")
show(cx+cy+po+q+pd+pb+cr,xmax=1.42,xmin=0,ymax=1.42,ymin=0,
gridlines="minor",figsize=5,fontsize=6,gridlinesstyle=dict(
color="lightgreen",alpha=0.3,linestyle="-"),frame=True,axes=False)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
sqrt(2.0)/2,deg(atan(0.6/0.725))
# Out:
# (0.707106781186548, 39.6106882400266)
