# %%
# %display latex
ce=circle((0,0),1.41,color="red")
ci=circle((0,0),1,color="black")
show(ce+ci,xmin=-1.5,xmax=1.5,ymin=-1.5,ymax=1.5,
gridlines="minor",figsize=5,fontsize=5,
gridlinesstyle=dict(color="lightgreen",
linestyle="-",alpha=0.3),frame=False,axes=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
c3=circle((0,0),3,color="black")
a1 = arc((0,0), 3, angle=pi/4, 
sector=(pi/4,1*pi/-4),thickness=2)
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,0.9*pi/6),thickness=2)
a3 = arc((0,0), 2, angle=pi/2.45,color="green", 
sector=(pi/11,1*pi/-11),thickness=2)
show(ci+a1+a2+a3+c3,xmin=-3,xmax=3,ymin=-3,ymax=3,
     gridlines="minor",figsize=5,fontsize=8,
     gridlinesstyle=dict(color="lightgreen",linestyle="-"),
     frame=False,axes=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
dr=x;nr=plot(dr,x,0,2,color="red",linestyle="--")
lb=text("$\\frac{\\pi}{2}=c$",(.6,2.35),color="red",fontsize=18)
c1=circle((0,0),1,color="orange",linestyle="--")
show(ce+ci+a1+a2+a3+nr+lb+c1+c3,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 9 graphics primitives

# %% [markdown]
# ###### <font color='red'>Comment calculer le degré de l'arc ?</font>
#
# <font color='blue'>L'arc bleu mesure $\frac{\pi}{2}$, le rayon $r=1$</font>

# %%
ce=circle((0,0),2.85,color="red");ci=circle((0,0),2,color="black")
show(ce+ci,xmin=-3,xmax=3,ymin=-3,ymax=3,gridlines="minor",
figsize=5,fontsize=8,gridlinesstyle=dict(color="lightgreen",
linestyle="-",alpha=0.3),frame=False,axes=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a1 = arc((0,0), 2.85, angle=pi/4,sector=(pi/4,1*pi/-4))
a2=arc((0,0),2,angle=pi/6,color="red",sector=(pi/-6,0.9*pi/6))
a3=arc((0,0),2,angle=pi/2.45,color="green",sector=(pi/11,1*pi/-11))
show(ce+ci+a1+a2+a3,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=8,gridlinesstyle=dict(
color="lightgreen",linestyle="-"),frame=False,axes=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
dr=x;nr=plot(dr,x,0,1.41,color="red",linestyle="--")
lb=text("$\\frac{\\pi}{2}=c$",(.6,2.35),color="red",fontsize=18)
c1=circle((0,0),1,color="orange",linestyle="--")
show(ce+ci+a1+a2+a3+nr+lb+c1,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# ###### <font color='red'>Comment calculer le degré de l'arc ?</font>
#
# <font color='blue'>L'arc bleu mesure $\frac{\pi}{4}$, le rayon $r=2,85$</font>

# %%
la=x*pi/2;al=plot(la,x,0 ,1.5,color="blue",linestyle="--")
lt=text("$\\frac{\\pi}{2}:45^o$",(2.4,2.6),
color="blue",fontsize=18)
show(ce+ci+a1+a2+a3+nr+al+lt,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=5,fontsize=8,
frame=True,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# $\color{red}{\text{Ici 45°= $\frac{\pi}{4}$}}$
#
# $\color{blue}{\text{Rayon en bleu $\frac{\pi}{4}$}}$

# %%
lx=x*pi/6;xl=plot(lx,x,0 ,2.5,color="orange",linestyle="--")
show(ce+ci+a1+a2+a3+nr+al+xl,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
dr=x*pi/2;nr=plot(dr,x,0,1.047,color="red",linestyle="--")
lx=x*pi/6;xl=plot(lx,x,0 ,2.5,color="orange",linestyle="--")
show(ce+ci+a1+nr+a2+a3+al+xl,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
deg(x)=x*180/n(pi);

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
(deg(atan(1.75/1)))
# Out:
# 60.2551187030578

# %%
a1 = arc((0,0), 3, angle=pi/4,color="blue", 
sector=(pi/4,1*pi/-4))
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,0.9*pi/6),thickness=2)
a3 = arc((0,0), 2, angle=pi/2.4,color="green", 
sector=(pi/12,1*pi/-16),thickness=2)
show(ce+ci+a1+nr+a2+a3+al+xl+pn+pp,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines=False,gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
ln(i)
# Out:
# 1/2*I*pi

# %%
dr=x*pi/1.79;nr=plot(dr,x,0,1.41,color="red",linestyle="--")
lx=x*pi/5.5;xl=plot(lx,x,0 ,2.5,color="orange",linestyle="--")
pn=point([1.75,1],color="red");
pp=point([1,1.75],color="red")
show(ce+ci+a1+nr+a2+a3+al+xl+pn+pp,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
c0=circle((0,0),1,color="red");p0=point([0,pi/2],color="red")
l0=line([[0,0],[0,pi/2]],thickness=2)
show(c0+l0+p0,xmin=-3.5,xmax=3.5,ymin=-3.5,ymax=3.5,
gridlines=True,gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=6,frame=True,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives
