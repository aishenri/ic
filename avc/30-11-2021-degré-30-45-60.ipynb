# %%
# %display latex
ce=circle((0,0),3,color="red")
ci=circle((0,0),2,color="black")
a1 = arc((0,0), 3, angle=pi/4, 
sector=(pi/4,pi/-4),thickness=1)
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,0.9*pi/6),thickness=1)
a3 = arc((0,0), 2, angle=pi/2.45,color="green", 
sector=(pi/11,1*pi/-11),thickness=1)
show(ci+ce+a1+a2+a3,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=8,
gridlinesstyle=dict(color="lightgreen",linestyle="-"),
frame=False,axes=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
a3 = arc((0,0), 2, angle=pi/2.45,color="green", 
sector=(pi/12,1*pi/-14),thickness=1)
show(ce+a1+a2+a3,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=8,
gridlinesstyle=dict(color="lightgreen",linestyle="-"),
frame=False,axes=True)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
deg(x)=x*180/n(pi);deg(atan(1.79/1.45))
# Out:
# 50.9905947179248

# %%
dr=x*pi/1.79;nr=plot(dr,x,0,1.45,color="red",linestyle="--")
lx=x*pi/5.5;xl=plot(lx,x,0 ,2.6,color="orange",linestyle="--")
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,0.86*pi/5),thickness=1)
show(ci+ce+a1+a2+a3+nr+xl,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=8,
gridlinesstyle=dict(color="lightgreen",linestyle="-"),
frame=False,axes=True)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
lt=text("$\\frac{\\pi}{6}:30^o$",(0.9,2.4),color="red",fontsize=6)
lb=text("$\\frac{\\pi}{6}:30^o$",(2.4,0.75),color="orange",fontsize=6)
show(ci+ce+a1+a2+a3+nr+xl+lt+lb,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines=False,figsize=5,fontsize=8,
gridlinesstyle=dict(color="lightgreen",linestyle="-"),
frame=False,axes=True)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
lq=text("$\\frac{\\pi}{2}:45^o$",(1.8,1.8),color="blue",fontsize=6)
db=x;nb=plot(db,x,0,1.41,color="blue",linestyle="--")
show(ci+ce+a1+a2+a3+nr+xl+lt+lb+nb+lq,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines=False,figsize=5,fontsize=8,
gridlinesstyle=dict(color="lightgreen",linestyle="-"),
frame=False,axes=True)
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
a4 = arc((0,0), 2, angle=pi/8,color="blue", 
sector=(pi/4.7,-1*pi/-22),thickness=1)
show(ci+ce+a1+a2+a3+nr+xl+lt+lb+nb+lq+a4,xmin=-3,xmax=3,
ymin=-3,ymax=3,gridlines=False,figsize=3,fontsize=5,
gridlinesstyle=dict(color="lightgrey",linestyle="-"),
frame=False,axes=True)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
deg(3.1415/4)
# Out:
# 44.9986728350870
