# %% [markdown]
# ###### Dipôle lumière
#
# $LC\Omega^2=1=\mu\epsilon c^2$
#
# Impédance(inductance) : $Lic$ (dériver c'est multiplier par : $ic$)
#
# Impédance (capacitive) : $\frac{-i}{Cc}$  (intégrer c'est diviser par : $ic$)

# %%
# %display latex
i*i,i/i
# Out:
# (-1, 1)

# %%
c=299792458;(i/c),(-i/c)
# Out:
# (1/299792458*I, -1/299792458*I)

# %%
(c/i)^2,(c/-i)^2
# Out:
# (-89875517873681764, -89875517873681764)

# %%
(c/i)^2*(c/-i)^2
# Out:
# 8077608713062490229263800746151696

# %%
ç=3141592654
(c/i)*(c/-i),(ç^i^2)
# Out:
# (89875517873681764, 1/3141592654)

# %% [markdown]
# Pour démontrer le caractère couple lumière on a besoin de $i$

# %%
e^(i*pi),(i/c)/(-i/c)
# Out:
# (-1, -1)

# %%
n(e^(i*c)^2)
# Out:
# 6.36378158220173e-39032441470737084

# %%
n((e^(i*c)^-2)/n(e^(i*c)^2),digits=50)
# Out:
# 1.5713927121521699046109012424354459256942101064814e39032441470737083

# %%
sqrt(n((e^(i*c)^2),digits=50))
# Out:
# 3.0337541213597435581580939313153201802347580597001e-19516220735368536

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
e^(i*pi)
# Out:
# -1

# %%
deg(x)=x*180/n(pi)
deg(-cos(pi)+i*sin(pi))
# Out:
# 57.2957795130823

# %% [markdown]
# http://villemin.gerard.free.fr/Wwwgvmm/Type/aaaCompl/PuisImag.htm

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n(ln(i))
# Out:
# 1.57079632679490*I

# %%
n(-2*i)
# Out:
# -2.00000000000000*I

# %%
n((ln(i))*-2*i,digits=35)
# Out:
# 3.1415926535897932384626433832795029

# %%
# %display latex
ce=circle((0,0),3,color="red")
ci=circle((0,0),2,color="black")
a1 = arc((0,0), 3, angle=pi/4, 
sector=(pi/4,pi/-4),thickness=1)
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,0.9*pi/6),thickness=1)
a3 = arc((0,0), 2, angle=pi/2.45,color="green", 
sector=(pi/11,1*pi/-11),thickness=1)
show(ci+ce+a1+a2+a3,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=8,
gridlinesstyle=dict(color="lightgreen",linestyle="-"),
frame=False,axes=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
deg(x)=x*180/n(pi);deg((3.1415/3.1415))
# Out:
# 57.2957795130823

# %%
dr=x*pi/1.77;nr=plot(dr,x,0,1.5,color="red",linestyle="--")
lx=x*-pi/1.77;xl=plot(lx,x,0 ,1.5,color="orange",linestyle="--")
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,0.86*pi/5),thickness=1)
show(ci+ce+a1+a2+a3+nr+xl,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=8,
gridlinesstyle=dict(color="lightgreen",linestyle="-"),
frame=False,axes=True)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
90-57.2957795130823
# Out:
# 32.7042204869177

# %%
30-2.70422048691770
# Out:
# 27.2957795130823

# %%
2/3.0
# Out:
# 0.666666666666667

# %%
deg(1.77/3.14)
# Out:
# 32.2973024643808

# %% [markdown]
# Le radian est la racine carrée de pi /pi

# %%
sqrt(pi)/pi,pi/sqrt(pi)
# Out:
# (1/sqrt(pi), sqrt(pi))

# %%
factorial(1/2)
# Out:
# 1/2*sqrt(pi)

# %%
sqrt(pi)/2
# Out:
# 1/2*sqrt(pi)

# %%
sqrt(3.1415)/3.1415
# Out:
# 0.564197903427560

# %%
n(deg(sqrt(pi)/pi))+deg(-1)
# Out:
# -24.9700975305523

# %%
1/(25-24.9700975305523)
# Out:
# 33.4420540667745

# %%
rad(x)=x*n(pi)/180;rad(171.887338539247)
# Out:
# 3.00000000000000

# %%
180-deg(1)*3
# Out:
# 8.11266146075303

# %%
n(pi)-3*2
# Out:
# -2.85840734641021

# %%
sqrt(141592.6)
# Out:
# 376.287921677005

# %%
mu=n(pi)*4E-7;c=299792458;ep=1/(mu*c*c)
Z=mu/ep;Z
# Out:
# 141925.729081004

# %%
Z-(n(pi)-3)
# Out:
# 141925.587488350

# %%
(n(pi)-3)*1000000
# Out:
# 141592.653589793

# %%
(120*n(pi))^2
# Out:
# 142122.303375687

# %%
r=2/sqrt(n(pi));r
# Out:
# 1.12837916709551

# %%
1.12837916709551,2.85840734641021
# Out:
# (1.12837916709551, 2.85840734641021)

# %%
2.85840734641021-1.2837916709551
# Out:
# 1.57461567545511

# %%
1.57461567545511*2
# Out:
# 3.14923135091022

# %%
rad(1)
# Out:
# 0.0174532925199433

# %%
1/(2*n(pi))
# Out:
# 0.159154943091895

# %%
1/(1/(2*n(pi)))
# Out:
# 6.28318530717959
