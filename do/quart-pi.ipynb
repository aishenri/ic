# %%
cx=circle((0,0),sqrt(2.0),color="red")
q=circle((0,0),1,color="green")
cy=circle((0,0),1,color="black");r=2/sqrt(n(pi))
ax = arc((0,0), sqrt(2.0), angle=pi/4, 
sector=(pi/4,1*pi/-4),thickness=2)
ay = arc((0,0), 1, angle=pi/6,color="red", 
sector=(pi/-6,0.9*pi/6),thickness=2)
az = arc((0,0), 1, angle=pi/2.7,color="green", 
sector=(pi/7.5,1*pi/-7.85),thickness=2)
po=polygon([[0,0],[0,1],[1,1],[1,0]],fill=False)
dr=x;nr=plot(dr,x,-1,1,color="black",linestyle="--")
show(cx+cy+po+q,xmax=1.42,xmin=0,ymax=1.42,ymin=0,
gridlines="minor",figsize=5,fontsize=4,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=True,axes=False)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
d=x;pd=plot(d,x,0,1,color="red")
show(cx+cy+po+q+pd,xmax=1.42,xmin=0,ymax=1.42,ymin=0,
gridlines="minor",figsize=5,fontsize=4,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=True,axes=False)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
# %display latex
solve(x^2==-25,x)
# Out:
# [x == (-5*I), x == (5*I)]

# %%
a=1;b=1;c=1

# %%
b^2+a*b-a^2-1==0
# Out:
# True

# %%
b^3+a^2*b-a^3==1
# Out:
# True

# %%
eq2=x^3+a*x;eq2
# Out:
# x^3 + x

# %%
eq1=a*b^2;eq1
# Out:
# 1

# %%
f=sqrt(1-x^2);g=plot(f)
show(g,figsize=3,fontsize=4,aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(pi,digits=35)
# Out:
# 3.1415926535897932384626433832795029

# %%
31415926535897932384626433832795029/\
10000000000000000000000000000000000
# Out:
# 31415926535897932384626433832795029/10000000000000000000000000000000000

# %%
f3=x^3+x;g3=plot(f3,x,0,0.7)

# %%
f3=x^3+x;g3=plot(f3,x,0,0.59)
g4=plot(-f3,x,-0.59,0)
x1=x;x3=plot(x1,x,0,0.7,color="red")
x2=-x;x4=plot(x2,x,-0.7,0,color="orange")
show(g+g3+g4+x3+x4,xmax=1,ymax=1,axes=True,
figsize=5,fontsize=4,gridlines="minor",
     aspect_ratio=1,frame=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
integral(f3,x,0,0.8)
# Out:
# 0.4224000000000001

# %%
integral(x1,x,0,0.7079)
# Out:
# 0.250561205

# %%
sqrt(12.3456789)
# Out:
# 3.51364182864446

# %% [markdown]
#  ![image.png](attachment:image.png)
