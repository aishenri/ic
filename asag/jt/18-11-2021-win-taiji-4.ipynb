# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Argand dans son essai dessine une même figure 1. Les autres sont le taiji, datant d'environ 10000 ans.
#
# Nord/Sud : quantité médiane, Ouest/Est : quantité prime. $z=a+bi$ et respectivement : $i,i^2;i^3;i^4$

# %%
# %display latex
show(LatexExpr(r"i=\sqrt-1 : i^2=-1 : i^3=-\sqrt-1=-i : i^4=1"))
# Out:
# i=\sqrt-1 : i^2=-1 : i^3=-\sqrt-1=-i : i^4=1

# %%
-1/((i^2)/4)   # inverse négatif de 4
# Out:
# 4

# %%
(i^2)/3
# Out:
# -1/3

# %%
(i^2)/2
# Out:
# -1/2

# %%
(i^2)/-4
# Out:
# 1/4

# %%
T=matrix([[8,1,6],[3,5,7],[4,9,2]]);T
# Out:
# [8 1 6]
# [3 5 7]
# [4 9 2]

# %%
Ti=matrix([[,1,6],[3,5,7],[-1/((i^2)/4),9,2]]);Ti
# Out:
# [8 1 6]
# [3 5 7]
# [4 9 2]

# %%
-1/((i^2)/4)*2
# Out:
# 8

# %%
i^4*i^4
# Out:
# 1

# %%
((pi)/2*i)
# Out:
# 1/2*I*pi

# %%
(i*pi/2)
# Out:
# 1/2*I*pi

# %%
log(sqrt(-1))
# Out:
# 1/2*I*pi

# %%
n(sqrt(e^(i*pi/2)/log(sqrt(-1))))
# Out:
# 0.797884560802865

# %%
deg(x)=x*180/n(pi);deg(0.797884560802865)
# Out:
# 45.7154178726535
