# %%
# %display latex

# %%
ce=circle((0,0),2.85,color="red");ci=circle((0,0),2,color="black")
show(ce+ci,xmin=-3,xmax=3,ymin=-3,ymax=3,gridlines="minor",
figsize=5,fontsize=8,gridlinesstyle=dict(color="lightgreen",
linestyle="-",alpha=0.3),frame=False,axes=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,pi/6),thickness=2)
a3 = arc((0,0), 2, angle=pi/2.44,color="blue", 
sector=(pi/11,pi/-11),thickness=2)
show(ci+a2+a3,xmin=-2,xmax=2,ymin=-2,ymax=2,
     gridlines="minor",figsize=5,fontsize=6,
gridlinesstyle=dict(color="lightgreen",
linestyle="-",alpha=0.3),frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
r=2/sqrt(n(pi));r
a2 = arc((0,0), r, angle=pi/6,color="red", 
sector=(pi/-6,pi/6),thickness=2)
a3 = arc((0,0), r, angle=pi/3,color="blue", 
sector=(pi/11,pi/-11),thickness=2)
c1=circle((0,0),r,color="black")
show(c1+a2+a3,xmin=-r,xmax=r,ymin=-r,ymax=r,
gridlines="minor",figsize=5,fontsize=6,
gridlinesstyle=dict(color="lightgreen",
linestyle="-",alpha=0.3),frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
r=2/sqrt(n(pi));r
p1=polygon(((-1,1),(1,1),(1,-1),(-1,-1)),
color="yellow",alpha=0.5,thickness=1)
show(c1+a2+a3+p1,xmin=-r,xmax=r,ymin=-r,ymax=r,
gridlines="minor",figsize=5,fontsize=6,
gridlinesstyle=dict(color="lightgreen",
linestyle="-",alpha=0.5),frame=False,axes=True)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
show(sin(1.0));deg(x)=x*180/n(pi)
L=2*n(pi)*1*(sin(1.0)/360)
show(deg(sin(1.0))," = ",L)
# Out:
# 0.841470984807897
# 48.2127360122095 ' = ' 0.0146864392448970

# %%
show(cos(1.0));deg(x)=x*180/n(pi)
L=2*n(pi)*1*(cos(1.0)/360)
show(deg(1)," = ",L)
# Out:
# 0.540302305868140
# 57.2957795130823 ' = ' 0.00943005419351652

# %%
n(pi)/4
# Out:
# 0.785398163397448

# %%
deg(n(pi)/6)
# Out:
# 30.0000000000000

# %%
1/n(pi)*0.5
# Out:
# 0.159154943091895

# %%
from sage.plot.plot import graphics_array
r=2/sqrt(n(pi));r
p3=plot(circle((0,0),r,color="red",fill=True,alpha=0.2,)+\
polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2,
        thickness=1,frame=True,axes=True));
p2= circle((0,0),r,color="red",
        fill=True,alpha=0.2,fontsize=6)  
p1=polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2,
       thickness=1,frame=True,axes=True);
g = graphics_array([p1,p2,p3]);
g.show(frame=False,figsize=10,gridlines="minor",gridlinesstyle=dict(color="cyan",
linestyle="-",alpha=0.7))
# Out:
# Graphics Array of size 1 x 3

# %%
p1=polygon(((-1,1),(1,1),(1,-1),(-1,-1)),
color="yellow",alpha=0.5,thickness=1)
show(c1+a2+a3+p1,xmin=-r,xmax=r,ymin=-r,ymax=r,
gridlines="minor",figsize=5,fontsize=6,
gridlinesstyle=dict(color="lightgreen",
linestyle="-",alpha=0.5),frame=False,axes=True)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
sin(0.8)+cos(0.8)
# Out:
# 1.41406280024669

# %%
# %display latex
var("y")
d=x;di=plot(d,x,-2,2,color="black")
dn=-x;ni=plot(dn,x,-2,2,color="orange")
d1=x/2.5;n1=plot(d1,x,-2.65,2.65,color="green")
d2=x*2.5;n2=plot(d2,x,-1.06,1.06,color="violet")
ce=circle((0,0),2.85,color="red")
ci=circle((0,0),2,color="black")
h = implicit_plot(x^2+y^2-8, (-3,3), (-3,3),plot_points=4)
show(ce+ci,figsize=4,axes=True,
aspect_ratio=1,gridlines="Minor",frame=False,fontsize=6)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a1 = arc((0,0), 2.85, angle=pi/4, 
sector=(pi/4,1*pi/-4),thickness=2)
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,0.9*pi/6),thickness=2)
a3 = arc((0,0), 2, angle=pi/2.45,color="green", 
sector=(pi/11,1*pi/-11),thickness=2)
show(ce+ci+a1+a2+a3,xmin=-3,xmax=3,ymin=-3,ymax=3,
     gridlines="minor",figsize=5,fontsize=8,
     gridlinesstyle=dict(color="lightgreen",linestyle="-"),
     frame=False,axes=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
dr=x*pi/2;nr=plot(dr,x,0,1.047,color="red",linestyle="--")
lb=text("$\\frac{\\pi}{2}=c$",(.6,2.35),color="red",fontsize=18)
c1=circle((0,0),1,color="orange",linestyle="--")
show(ce+ci+a1+a2+a3+nr+lb+c1,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# ###### <font color='red'>Comment calculer le degré de l'arc ?</font>
#
# <font color='blue'>L'arc bleu mesure $\frac{\pi}{2}$, le rayon $r=1$</font>

# %%
la=x*pi/pi;al=plot(la,x,0 ,2,color="blue",linestyle="--")
lt=text("$\\frac{\\pi}{2}:45^o$",(2.4,2.6),
color="blue",fontsize=18)
show(ce+ci+a1+a2+a3+nr+al+lt,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=5,fontsize=8,
frame=True,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# $\color{red}{\text{Ici 45°= $\frac{\pi}{\pi}$}}$
#
# $\color{blue}{\text{Rayon en bleu $\frac{\pi}{\pi}$}}$

# %%
lx=x*pi;xl=plot(lx,x,0 ,0.6,color="orange",linestyle="--")
show(ce+ci+a1+a2+a3+nr+al+xl,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
la=x*pi^pi;al=plot(la,x,0 ,0.055,color="blue",linestyle="--")
lq=x*pi/5;ql=plot(lq,x,0 ,1.7,color="violet",linestyle="--")
show(ci+a2+a3+nr+al+xl+ql,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="white",
linestyle="-"),figsize=5,fontsize=8,frame=False,axes=True)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
el=ellipse((0,0),2,1,color="blue")
hv=line([(0,0),(2,1)],color="red",linestyle=":")
vh=line([(1,1),(1,1.5)],color="green",linestyle="-")
l=line([(3.4,1),(3.4,2)],color="green",linestyle="-")
show(ci+a2+a3+nr+al+xl+ql+hv+vh+l+el,
xmin=-2,xmax=2,ymin=-2,ymax=2,
gridlines="minor",gridlinesstyle=dict(color="white",
linestyle="-"),figsize=5,fontsize=5,frame=False,axes=True)
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
2*3.1415*1*180/360
# Out:
# 3.14150000000000

# %%
360*3.1415/360
# Out:
# 3.14150000000000

# %%
p=6.28318530717959
6.28318530717959*1*180/360
# Out:
# 3.14159265358979

# %%
n(pi)*2
# Out:
# 6.28318530717959

# %%
p*1000*3.28279/360
# Out:
# 57.2954941515447

# %%
deg(x)=x*180/n(pi);deg(1)
# Out:
# 57.2957795130823

# %%
6.28318530717959*1*180/360
