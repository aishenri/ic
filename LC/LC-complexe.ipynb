# %% [markdown]
# Facteur de Qualité $Q=\frac{1}{R}\sqrt\frac{L}{C}$

# %%
R=376.72;L=n(pi)*4E-7;c=229792458;C=1/(L*c^2)
Q=1/R*(sqrt(L/C));Q
# Out:
# 0.766526117968933

# %%
deg(x)=x*180/n(pi);deg(0.766526117968933)#44 °
# Out:
# 43.9187114461669

# %%
deg(1/L),deg(1/C)
# Out:
# (4.55945326390520e7, 3.80192931026509e12)

# %%
deg(1/C)/deg(1/L)
# Out:
# 83385.6405627176

# %%
deg(1/L)/deg(1/C)
# Out:
# 0.0000119924724838908

# %%
1/(deg(1/C)/deg(1/L))*(deg(1/L)/deg(1/C))
# Out:
# 1.43819396276878e-10

# %%
(deg(1/C)/deg(1/L))*(deg(1/L)/deg(1/C))
# Out:
# 1.00000000000000

# %%
# %display latex
n(sqrt(i))
# Out:
# 0.707106781186548 + 0.707106781186547*I

# %% [markdown]
# https://fr.wikipedia.org/wiki/Intrication_quantique
#
# j'en déduit que iq est un yin yang couplé = taiji
#
# Pour des angles de 0°, 30° et 60°, on a les trois règles : Pourquoi n'ont ils pas choisi 45° qui donnerait 50% (1/2)

# %% [markdown]
# https://fr.wikipedia.org/wiki/Logarithme_complexe#D%C3%A9termination_principale
#
# $ln(x^2)=2 ln x$ pour x=-1 (à voir avec Gauss ?)
#
# $ln((-1)^2)= 2 ln(-1)$=$2(ln 1 +i\pi)$=$2i\pi$
#
# $ln((-1)^2)= ln 1=0$
#
# Cela imposerait l'existence d'au moins deux valeurs différentes, chacune acceptable, comme un logarithme de 1 : 0 et 2iπ.

# %%
lx=log(x^2,4);xl=plot(lx,x,0,2,color="red")
le=log(x,e);el=plot(le,x,0,e,color="blue")
ld=log(x,10);dl=plot(ld,x,0,10,color="green")
show(xl+el+dl,ymin=-1/2,gridlines="minor",
fontsize=5,figsize=3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
nl=ln(2.71);ll=plot(nl,x,0,10,color="orange",
linestyle="--")
show(xl+el+dl+ll,ymin=-1/2,gridlines="minor",
fontsize=5,figsize=3,frame=False,axes=True)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
ln(e),log(1)
# Out:
# (1, 0)
