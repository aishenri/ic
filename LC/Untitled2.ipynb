# %% [markdown]
# file:///C:/Users/henri/Downloads/TP_Constante_de_Planck_fiche_223150.pdf

# %%
# %display latex
sqrt(x)
# Out:
# sqrt(x)

# %%
b=465;o=605;v=525;j=590;r=630 # nm

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
w=2*(n(pi));c=299792458

# %% [markdown]
# La circonférence d'un cercle de $c=2 \pi$ est égale à la longueur d'onde fondamentale $\lambda=2\pi$

# %%
4E-7*n(pi,digits=30)
# Out:
# 1.25663706143592e-6

# %%
u=1/n(pi)*360E-8;u
# Out:
# 1.14591559026165e-6

# %%
s=1/(n(pi)*360E+8);s
# Out:
# 8.84194128288307e-12

# %%
L=n(pi)*4E-7;L
# Out:
# 1.25663706143592e-6

# %%
C=1/(L*c*c);C
# Out:
# 8.85418781762039e-12
