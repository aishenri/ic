# %% [markdown]
# https://www.apmep.fr/IMG/pdf/Article_probleme_Bale.pdf
#
# L'inverse de la factorielle donne un résultat plus facile à reproduire, car le carré est entier.(page 6)

# %%
# %display latex
euler=factorial(1/2);
show(LatexExpr
(r"Euler=\frac{1}{2}!=\frac{\sqrt \pi}{2}="),n(euler))
# Out:
# Euler=\frac{1}{2}!=\frac{\sqrt \pi}{2}= 0.886226925452758

# %%
show(LatexExpr(r"Inverse= \frac{2}{\sqrt \pi}="),
n(1/euler))
# Out:
# Inverse= \frac{2}{\sqrt \pi}= 1.12837916709551

# %% [markdown]
# Ce sont les prémisses du relativisme : Blanc bonnet et bonnet blanc
# !
#
# Tout dépend de quelle côté de la lorgnette regarde l'observateur, plus + grand, moins - petit !
#
# Je pourrais appeler cela la théorie des inverses, mais il y a déjà trop de théories !
#
# Carré égale exposant plus (+), racine égale exposant moins (-)

# %%
e=1/(2*n(pi))*1E-18;e # exposant moins -²
# Out:
# 1.59154943091895e-19

# %%
ei=(2*n(pi))*1E-19;ei # exposant ^+1 +²
# Out:
# 6.28318530717959e-19

# %% [markdown]
# Dérivé=La vitesse de la lumière devrait être 2c 2x ou 2pi.
#
# Accélération c² x² ou $\pi^2$, donc zeta(2) est une accélération, couplé d'une vitesse =2
#
# Ce que je ne comprends pas, c'est pourquoi Maxwell et Einstein ont interprêté la fréquence propre comme une vitesse ?
#
# Ils ont identifié le rapport $\frac{Qe}{Qm}=c$, ce qui n'est pas du calcul mais une intuition. En d'autre terme plus simple : $\frac{c^2}{c}=c$, ce qui démontre que $Qe$ est un carré, une particule double !

# %%
dr=x*pi/2;nr=plot(dr,x,0,1.047,color="red",linestyle="--")
ce=circle((0,0),2.85,color="red");ci=circle((0,0),2,color="black")
a1 = arc((0,0), 2.85, angle=pi/4,sector=(pi/4,1*pi/-4),thickness=2)
a2 = arc((0,0), 2, angle=pi/6,color="red",sector=(pi/-6,0.9*pi/6))
a3 = arc((0,0), 2, angle=pi/2.7,color="green",sector=(pi/8,1*pi/-8))
la=x*pi/pi;al=plot(la,x,0 ,2,color="blue",linestyle="--")
lb=text("\u2630",(2.4,2.6),color="blue",fontsize=18)
lt=text("$\\frac{\\pi}{4}:45^o $",(2.4,2.6),color="blue",fontsize=18)
li=text("$i$",(-0.2,2.5),color="red",fontsize=18)
show(ce+ci+a1+a2+a3+al+lt+li,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=5,fontsize=8,
frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
pd=n(pi)-3;pd
# Out:
# 0.141592653589793

# %%
dp=sqrt(2.0);dp
# Out:
# 1.41421356237310

# %%
rp=sqrt((dp/pd-9)*10);rp # rapport x10
# Out:
# 3.14309099723209

# %%
sqrt(137.0),sqrt(72.0)
# Out:
# (11.7046999107196, 8.48528137423857)

# %%
sqrt(137.0)/sqrt(72.0)
# Out:
# 1.37941211310390

# %%
sqrt(138.0)*sqrt(74.0)
# Out:
# 101.054440773278

# %%
136/2.0,72/2.0
# Out:
# (68.0000000000000, 36.0000000000000)

# %%
show(ce+ci+a1+a2+a3+al+lt+li,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=5,fontsize=8,
frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
n(pi)
# Out:
# 3.14159265358979
