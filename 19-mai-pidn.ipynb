# %% [markdown]
# #   $\pi dn$ = $\pi ç$

# %% [markdown]
# La forme donne une idée de son contenant : Ici il s'agit du cercle. Toute forme sinusoidale a pour origine un cercle, fermé ou ouvert.

# %%
n(pi,digits=33)
# Out:
# 3.14159265358979323846264338327950

# %% [markdown]
# La 32 ième décimale ferme le cercle de $\pi. 0$. $\pi^-$ est le rayon négatif, $\pi^+$ est le rayon positif. Deux est neutre pour la surface ou l'aire d'un cercle. 2+2=4 et 2*2=4

# %%
p=plot(sqrt(1-x^2),x,-1,1);
show(p,aspect_ratio=1,figsize=2,fontsize=5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Il y a une erreur dans la définition du spin : Seule observable quantique qui ne présente pas d'équivalent classique, faux ! L'équivalent classique est le pouvoir rotatoire, c'est le problème de la conception des scientifiques à défendre leur langage.
# La figure représente une polarisation $\pm$ (un anglais dirait polarisation gauche et un français dirait polarisation droite). Un daoiste dirait : dipôle $\pm$)

# %%
q=plot(-sqrt(1-x^2),x,-1,1,color="red");
show(q,aspect_ratio=1,figsize=2,fontsize=5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(p+q,aspect_ratio=1,axes=False,
     figsize=3,fontsize=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Ensuite vient la voie... Découplage.

# %%
# %display latex
aire=pi*2*2;périmètre=pi*(2+2);aire,périmètre
# Out:
# (4*pi, 4*pi)

# %%
show("aire=",aire," périmètre=",périmètre)
# Out:
# 'aire=' 4*pi ' périmètre=' 4*pi

# %%
n(pi)*(2*2)
# Out:
# 12.5663706143592

# %%
n(pi)*(2+2)
# Out:
# 12.5663706143592

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
3.1415/3
# Out:
# 1.04716666666667

# %%
3.141592653/6
# Out:
# 0.523598775500000

# %%
60/1.047
# Out:
# 57.3065902578797

# %%
deg(x)=x*180/n(pi);deg(1)
# Out:
# 57.2957795130823

# %%
6.28*1.047
# Out:
# 6.57516000000000

# %%
6.28/sqrt(2.0)
# Out:
# 4.44063058585152

# %%
6.626/1.047
# Out:
# 6.32855778414518

# %%
LA=55;104,110
# Out:
# (104, 110)

# %%
110.0/104.0
# Out:
# 1.05769230769231

# %%
65+62
# Out:
# 127

# %%
69*2
# Out:
# 138

# %%
138/127.0
# Out:
# 1.08661417322835

# %%
1047/523.0
# Out:
# 2.00191204588910

# %%
1047/65.0
# Out:
# 16.1076923076923

# %%
do=64;do5=1047

# %%
64^2
# Out:
# 4096

# %%
1024/64.0
# Out:
# 16.0000000000000

# %%
1047/1024.0
# Out:
# 1.02246093750000

# %%
82/73.0
# Out:
# 1.12328767123288

# %%
81/72.0
# Out:
# 1.12500000000000

# %%
q1=1;q2=2;q3=3;q4=4;q5=5
q2/q5
# Out:
# 2/5

# %%
mi=81;mi2=162;mi3=324

# %%
do=64;do1=128;do2=256;do3=512;do4=1024
# Out:
# 324

# %%
1024/64.0
# Out:
# 16.0000000000000

# %%
64^(1/3)
# Out:
# 4

# %%
3.141592653/2.99792548
# Out:
# 1.04792219618481
